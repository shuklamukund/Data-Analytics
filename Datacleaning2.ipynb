# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv('automotive')

# %%
dataset.head(5)
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
dataset.head(20)
# Out:
#     symboling  normalized-losses         make fuel-type aspiration  \
# 0           3                NaN  alfa-romero       gas        std
# 1           3                NaN  alfa-romero       gas        std
# 2           1                NaN  alfa-romero       gas        std
# 3           2              164.0         audi       gas        std
# 4           2              164.0         audi       gas        std
# 5           2                NaN         audi       gas        std
# 6           1              158.0         audi       gas        std
# 7           1                NaN         audi       gas        std
# 8           1              158.0         audi       gas      turbo
# 9           0                NaN         audi       gas      turbo
# 10          2              192.0          bmw       gas        std
# 11          0              192.0          bmw       gas        std
# 12          0              188.0          bmw       gas        std
# ...

# %%
dataset['normalized-losses'].mode()
# Out:
# 0    161.0
# Name: normalized-losses, dtype: float64

# %%
dataset.fillna(dataset['normalized-losses'].mode()[0],inplace=True)

# %%
dataset.head(20)
# Out:
#     symboling  normalized-losses         make fuel-type aspiration  \
# 0           3              161.0  alfa-romero       gas        std
# 1           3              161.0  alfa-romero       gas        std
# 2           1              161.0  alfa-romero       gas        std
# 3           2              164.0         audi       gas        std
# 4           2              164.0         audi       gas        std
# 5           2              161.0         audi       gas        std
# 6           1              158.0         audi       gas        std
# 7           1              161.0         audi       gas        std
# 8           1              158.0         audi       gas      turbo
# 9           0              161.0         audi       gas      turbo
# 10          2              192.0          bmw       gas        std
# 11          0              192.0          bmw       gas        std
# 12          0              188.0          bmw       gas        std
# ...

# %%
for i in dataset.select_dtypes(include="object").columns:
    print(i)
    dataset[i].fillna(dataset[i].mode()[0],inplace=True)
# Out:
# make
# fuel-type
# aspiration
# num-of-doors
# body-style
# drive-wheels
# engine-location
# engine-type
# num-of-cylinders
# fuel-system

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
dataset.select_dtypes(include='float64').columns
# Out:
# Index(['normalized-losses', 'wheel-base', 'length', 'width', 'height', 'bore',
#        'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'price'],
#       dtype='object')

# %%
from sklearn.impute import SimpleImputer

# %%
si=SimpleImputer(strategy='mean')
ar=si.fit_transform(dataset[['normalized-losses', 'wheel-base', 'length', 'width', 'height', 'bore',
       'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'price']])
ar
# Out:
# array([[  161. ,    88.6,   168.8, ...,   111. ,  5000. , 13495. ],
#        [  161. ,    88.6,   168.8, ...,   111. ,  5000. , 16500. ],
#        [  161. ,    94.5,   171.2, ...,   154. ,  5000. , 16500. ],
#        ...,
#        [   95. ,   109.1,   188.8, ...,   134. ,  5500. , 21485. ],
#        [   95. ,   109.1,   188.8, ...,   106. ,  4800. , 22470. ],
#        [   95. ,   109.1,   188.8, ...,   114. ,  5400. , 22625. ]])

# %%
new_dataset=pd.DataFrame(ar,columns=dataset.select_dtypes(include='float64').columns)

# %%
new_dataset.isnull().sum()
# Out:
# normalized-losses    0
# wheel-base           0
# length               0
# width                0
# height               0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# price                0
# dtype: int64

# %%
new_dataset
# Out:
#      normalized-losses  wheel-base  length  width  height  bore  stroke  \
# 0                161.0        88.6   168.8   64.1    48.8  3.47    2.68
# 1                161.0        88.6   168.8   64.1    48.8  3.47    2.68
# 2                161.0        94.5   171.2   65.5    52.4  2.68    3.47
# 3                164.0        99.8   176.6   66.2    54.3  3.19    3.40
# 4                164.0        99.4   176.6   66.4    54.3  3.19    3.40
# ..                 ...         ...     ...    ...     ...   ...     ...
# 200               95.0       109.1   188.8   68.9    55.5  3.78    3.15
# 201               95.0       109.1   188.8   68.8    55.5  3.78    3.15
# 202               95.0       109.1   188.8   68.9    55.5  3.58    2.87
# 203               95.0       109.1   188.8   68.9    55.5  3.01    3.40
# 204               95.0       109.1   188.8   68.9    55.5  3.78    3.15
#
#      compression-ratio  horsepower  peak-rpm    price
# ...
